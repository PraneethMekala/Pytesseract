# %%
from PIL import Image
import os
import pytesseract

# %%
os.getcwd()
# Out:
# '/Users/praneethmekala/Documents/Jupyter Notes'

# %%
os.chdir('/Users/praneethmekala/Documents/Jupyter Notes/pytesseract-master/tests/data')
os.getcwd()
# Out:
# '/Users/praneethmekala/Documents/Jupyter Notes/pytesseract-master/tests/data'

# %%
pytesseract.pytesseract.tesseract = os.getcwd()

# %%
Image.open('test.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x480 at 0x1203835D0>

# %%
print(pytesseract.image_to_string(Image.open('test.png')))
# Out:
# This is a lot of 12 point text to test the
# ocr code and see if it works on all types
# of file format.
#
# The quick brown dog jumped over the
# lazy fox. The quick brown dog jumped
# over the lazy fox. The quick brown dog
# jumped over the lazy fox. The quick
# brown dog jumped over the lazy fox.
